# %% [markdown]
# # Create data catalog

# %%
from typing import List
import os
import glob
import tarfile
import bz2
import betfairlightweight
from betfairlightweight import filters
import pandas as pd
import numpy as np
import datetime
import json
from unittest.mock import patch

pd.set_option('display.max_rows', 200)

# %%
# Change this certs path to wherever you're storing your certificates
certs_path = '/Users/guillaume_baquiast/Documents/tmp'

# Change these login details to your own
my_username = "your_email"
my_password = "your_password"
my_app_key = "your_app_key"

trading = betfairlightweight.APIClient(username=my_username,
                                       password=my_password,
                                       app_key=my_app_key,
                                       certs=certs_path)

listener = betfairlightweight.StreamListener(max_latency=None)

# %%
# loading from tar and extracting files
def load_markets(file_paths: List[str]):
    for file_path in file_paths:
        if os.path.isdir(file_path):
            for path in glob.iglob(file_path + '**/**/*.bz2', recursive=True):
                f = bz2.BZ2File(path, 'rb')
                yield f
                f.close()
        elif os.path.isfile(file_path):
            ext = os.path.splitext(file_path)[1]
            # iterate through a tar archive
            if ext == '.tar':
                with tarfile.TarFile(file_path) as archive:
                    for file in archive:
                        yield bz2.open(archive.extractfile(file))
            # or a zip archive
            elif ext == '.zip':
                with zipfile.ZipFile(file_path) as archive:
                    for file in archive.namelist():
                        yield bz2.open(archive.open(file))

    return None

# %%
metadata_dict = {
    "event_name": [],
    "event_id": [],
    "market_time": [],
    "open_date": [],
    "path": [],
}


def _get_sub_dir(path):
    return [f for f in os.listdir(path) if not f.startswith('.')]

base_path = "/Users/guillaume_baquiast/Documents/tmp/data/BASIC"

# for year in _get_sub_dir(base_path):
for year in ["2021"]:
    print(f"Scanning year {year}")
    for month in _get_sub_dir(base_path + "/" + year):
        print(f"  Scanning month {month}")
        for day in _get_sub_dir(base_path + "/" + year + "/" + month):
            print(f"    Scanning day {day}")
            for event_id in _get_sub_dir(base_path + "/" + year + "/" + month + "/" + day):
                market_path = base_path + "/" + year + "/" + month + "/" + day + "/" + event_id
                
                file_obj = next(load_markets([market_path]))

                stream = trading.streaming.create_historical_generator_stream(
                    file_path=file_obj,
                    listener=listener,
                )

                with patch("builtins.open", lambda f, _: f):   
                    gen = stream.get_generator()
                    market_books = next(gen())
                    market_book = market_books[0]

                    metadata_dict["event_name"].append(market_book.market_definition.event_name)
                    metadata_dict["event_id"].append(market_book.market_definition.event_id)
                    metadata_dict["market_time"].append(market_book.market_definition.market_time)
                    metadata_dict["open_date"].append(market_book.market_definition.open_date)
                    metadata_dict["path"].append(market_path)
# Out:
# Scanning year 2021
#   Scanning month Mar
#     Scanning day 18
#     Scanning day 9
#     Scanning day 16
#     Scanning day 17
#     Scanning day 10
#   Scanning month Feb
#     Scanning day 16
#     Scanning day 17
#     Scanning day 24
#     Scanning day 23
#   Scanning month May
#     Scanning day 29
#     Scanning day 30
#     Scanning day 4
#     Scanning day 5
#   Scanning month Apr
#     Scanning day 27
#     Scanning day 7
#     Scanning day 6
#     Scanning day 28
#     Scanning day 15
#     Scanning day 13
#     Scanning day 14

# %%
df_metadata = pd.DataFrame(metadata_dict)
df_metadata["date"] = df_metadata["market_time"].dt.strftime(date_format="%Y-%m-%d")
df_metadata.head()
# Out:
#                            event_name  event_id         market_time  \
# 0      San Francisco FC v Veraguas FC  30357677 2021-03-16 23:00:00
# 1  Sektzia Nes Tziona v MS Kfar Kasem  30339616 2021-03-09 17:00:00
# 2                 IA Akranes v Grotta  30339275 2021-03-09 20:00:00
# 3            EC Pelotas v Ypiranga RS  30338764 2021-03-08 23:00:00
# 4   Boca Juniors (W) v Tropico FC (W)  30338938 2021-03-08 22:30:00
#
#             open_date                                               path  \
# 0 2021-03-16 23:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 1 2021-03-09 17:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 2 2021-03-09 20:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 3 2021-03-08 23:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 4 2021-03-08 22:30:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
#
#          date
# 0  2021-03-16
# 1  2021-03-09
# 2  2021-03-09
# 3  2021-03-08
# 4  2021-03-08

# %% [markdown]
# # Select champions league

# %%
champion_league_games = pd.read_csv("europe-champions-league-2020-2021.csv")

champion_league_games = champion_league_games.replace(
    {
        "Paris Saint Germain": "Paris St-G",
        "Manchester City": "Man City",
        "Borussia Dortmund": "Dortmund",
        "Bayern München": "Bayern Munich",
        "Atlético Madrid": "Atletico Madrid",
        "Borussia M'gladbach": "Mgladbach"
    }
)

champion_league_games["event_name"] = champion_league_games["home_team"] + " v " + champion_league_games["away_team"]
champion_league_games["event_name_2"] = champion_league_games["away_team"] + " v " + champion_league_games["home_team"]

champion_league_games["date"] = (
    champion_league_games["date"].str[-4:] + "-" +
    champion_league_games["date"].str[-7:-5] + "-" +
    champion_league_games["date"].str[:-8]
)

champion_league_games = champion_league_games.sort_values("date")

champion_league_games = champion_league_games[champion_league_games["date"] > "2021"]

# %%
# Get the right one
(
    champion_league_games[["event_name", "date", "league", "country"]]
    .merge(df_metadata, on=["event_name", "date"], how="left")
)

tmp = (
    df_metadata
    .merge(
        champion_league_games[["event_name", "date", "league", "country"]],
        on=["event_name", "date"],
        how="right"
    )
    .sort_values("open_date")
)

tmp.to_csv("/Users/guillaume_baquiast/Documents/tmp/champions_league_metadata.csv", index=False)

tmp
# Out:
#                     event_name  event_id         market_time  \
# 0       Barcelona v Paris St-G  30186199 2021-02-16 20:00:00
# 1       Barcelona v Paris St-G  30186199 2021-02-16 20:00:00
# 2       RB Leipzig v Liverpool  30186224 2021-02-16 20:00:00
# 3       RB Leipzig v Liverpool  30186224 2021-02-16 20:00:00
# 4           Sevilla v Dortmund  30186201 2021-02-17 20:00:00
# 5           Sevilla v Dortmund  30186201 2021-02-17 20:00:00
# 6             Porto v Juventus  30186279 2021-02-17 20:00:00
# 7        Lazio v Bayern Munich  30186200 2021-02-23 20:00:00
# 8        Lazio v Bayern Munich  30186200 2021-02-23 20:00:00
# 9    Atletico Madrid v Chelsea  30186238 2021-02-23 20:00:00
# 10   Atletico Madrid v Chelsea  30186238 2021-02-23 20:00:00
# 13      Atalanta v Real Madrid  30186235 2021-02-24 20:00:00
# 11        Mgladbach v Man City  30186226 2021-02-24 20:00:00
# 12      Atalanta v Real Madrid  30186235 2021-02-24 20:00:00
# 22     Real Madrid v Liverpool  30366503 2021-04-06 19:00:00
# 23     Real Madrid v Liverpool  30366503 2021-04-06 19:00:00
# 24         Man City v Dortmund  30366490 2021-04-06 19:00:00
# 25         Man City v Dortmund  30366490 2021-04-06 19:00:00
# 26  Bayern Munich v Paris St-G  30366492 2021-04-07 19:00:00
# 27             Porto v Chelsea  30366489 2021-04-07 19:00:00
# 32       Real Madrid v Chelsea  30429977 2021-04-27 19:00:00
# 33       Real Madrid v Chelsea  30429977 2021-04-27 19:00:00
# 34       Paris St-G v Man City  30429978 2021-04-28 19:00:00
# 35       Paris St-G v Man City  30429978 2021-04-28 19:00:00
# 14          Dortmund v Sevilla       NaN                 NaT
# 15            Juventus v Porto       NaN                 NaT
# 16      Paris St-G v Barcelona       NaN                 NaT
# 17      Liverpool v RB Leipzig       NaN                 NaT
# 18        Man City v Mgladbach       NaN                 NaT
# 19      Real Madrid v Atalanta       NaN                 NaT
# 20       Bayern Munich v Lazio       NaN                 NaT
# 21   Chelsea v Atletico Madrid       NaN                 NaT
# 28             Chelsea v Porto       NaN                 NaT
# 29  Paris St-G v Bayern Munich       NaN                 NaT
# 30     Liverpool v Real Madrid       NaN                 NaT
# 31         Dortmund v Man City       NaN                 NaT
# 36       Man City v Paris St-G       NaN                 NaT
# 37       Chelsea v Real Madrid       NaN                 NaT
# 38          Man City v Chelsea       NaN                 NaT
#
#              open_date                                               path  \
# 0  2021-02-16 20:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 1  2021-02-16 20:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 2  2021-02-16 20:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 3  2021-02-16 20:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 4  2021-02-17 20:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 5  2021-02-17 20:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 6  2021-02-17 20:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 7  2021-02-23 20:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 8  2021-02-23 20:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 9  2021-02-23 20:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 10 2021-02-23 20:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 13 2021-02-24 20:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 11 2021-02-24 20:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 12 2021-02-24 20:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 22 2021-04-06 19:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 23 2021-04-06 19:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 24 2021-04-06 19:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 25 2021-04-06 19:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 26 2021-04-07 19:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 27 2021-04-07 19:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 32 2021-04-27 19:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 33 2021-04-27 19:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 34 2021-04-28 19:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 35 2021-04-28 19:00:00  /Users/guillaume_baquiast/Documents/tmp/data/B...
# 14                 NaT                                                NaN
# 15                 NaT                                                NaN
# 16                 NaT                                                NaN
# 17                 NaT                                                NaN
# 18                 NaT                                                NaN
# 19                 NaT                                                NaN
# 20                 NaT                                                NaN
# 21                 NaT                                                NaN
# 28                 NaT                                                NaN
# 29                 NaT                                                NaN
# 30                 NaT                                                NaN
# 31                 NaT                                                NaN
# 36                 NaT                                                NaN
# 37                 NaT                                                NaN
# 38                 NaT                                                NaN
#
#           date            league country
# 0   2021-02-16  Champions League  Europe
# 1   2021-02-16  Champions League  Europe
# 2   2021-02-16  Champions League  Europe
# 3   2021-02-16  Champions League  Europe
# 4   2021-02-17  Champions League  Europe
# 5   2021-02-17  Champions League  Europe
# 6   2021-02-17  Champions League  Europe
# 7   2021-02-23  Champions League  Europe
# 8   2021-02-23  Champions League  Europe
# 9   2021-02-23  Champions League  Europe
# 10  2021-02-23  Champions League  Europe
# 13  2021-02-24  Champions League  Europe
# 11  2021-02-24  Champions League  Europe
# 12  2021-02-24  Champions League  Europe
# 22  2021-04-06  Champions League  Europe
# 23  2021-04-06  Champions League  Europe
# 24  2021-04-06  Champions League  Europe
# 25  2021-04-06  Champions League  Europe
# 26  2021-04-07  Champions League  Europe
# 27  2021-04-07  Champions League  Europe
# 32  2021-04-27  Champions League  Europe
# 33  2021-04-27  Champions League  Europe
# 34  2021-04-28  Champions League  Europe
# 35  2021-04-28  Champions League  Europe
# 14  2021-03-09  Champions League  Europe
# 15  2021-03-09  Champions League  Europe
# 16  2021-03-10  Champions League  Europe
# 17  2021-03-10  Champions League  Europe
# 18  2021-03-16  Champions League  Europe
# 19  2021-03-16  Champions League  Europe
# 20  2021-03-17  Champions League  Europe
# 21  2021-03-17  Champions League  Europe
# 28  2021-04-13  Champions League  Europe
# 29  2021-04-13  Champions League  Europe
# 30  2021-04-14  Champions League  Europe
# 31  2021-04-14  Champions League  Europe
# 36  2021-05-04  Champions League  Europe
# 37  2021-05-05  Champions League  Europe
# 38  2021-05-29  Champions League  Europe
